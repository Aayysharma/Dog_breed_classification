# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle competitions download -c dog-breed-identification
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# dog-breed-identification.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dog-breed-identification.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# Importing the important Libraries

# %%
# Importing library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, Dropout
from keras.optimizers import Adam

# %% [markdown]
# Loading the labels data into dataframe and viewing the data.

# %%
labels_all = pd.read_csv('/content/labels.csv')
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
# Loading number or each breed
breed_all = labels_all['breed']
breed_count = breed_all.value_counts()
breed_count.head()
# Out:
# breed
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
# Name: count, dtype: int64

# %%
# Selecting all breeds because i have high computation power
CLASS_NAME = ['scottish_deerhound', 'maltese_dog', 'afghan_hound', 'entlebucher', 'bernese_mountain_dog']
labels = labels_all[(labels_all['breed'].isin(CLASS_NAME))]
labels = labels.reset_index()
labels.head()
# Out:
#    index                                id               breed
# 0      9  0042188c895a2f14ef64a918ed9c7b64  scottish_deerhound
# 1     12  00693b8bc2470375cc744a6391d397ec         maltese_dog
# 2     79  01e787576c003930f96c966f9c3e1d44  scottish_deerhound
# 3     80  01ee3c7ff9bcaba9874183135877670e         entlebucher
# 4     88  021b5a49189665c0442c19b5b33e8cf1         entlebucher

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAME)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):
    img = image.load_img('/content/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)
    x = np.expand_dims(img.copy(), axis=0)
    X_data[i] = x / 255.0

# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 588/588 [00:01<00:00, 441.26it/s]
# Train Images shape:  (588, 224, 224, 3)  size: 88,510,464
# One-hot encoded output shape:  (588, 5)  size: 2,940

# %% [markdown]
# Creating Convolutional Network layers

# %%
# Building the Model
model = Sequential()

model.add(Conv2D(filters = 8, kernel_size = (5,5), activation ='relu', input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 16, kernel_size = (3,3), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 32, kernel_size = (7,7), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 128, kernel_size = (5,5), activation ='relu', kernel_regularizer = 'l2'))
model.add(MaxPool2D(pool_size=(2,2)))



model.add(Flatten())
model.add(Dense(128, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(64, activation = "relu", kernel_regularizer = 'l2'))
model.add(Dense(len(CLASS_NAME), activation = "softmax"))

model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_26 (Conv2D)          (None, 220, 220, 8)       608
#
#  max_pooling2d_25 (MaxPooli  (None, 110, 110, 8)       0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 108, 108, 16)      1168
#
#  max_pooling2d_26 (MaxPooli  (None, 54, 54, 16)        0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 48, 48, 32)        25120
#
#  max_pooling2d_27 (MaxPooli  (None, 24, 24, 32)        0
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 20, 20, 64)        51264
#
#  max_pooling2d_28 (MaxPooli  (None, 10, 10, 64)        0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 6, 6, 128)         204928
#
#  max_pooling2d_29 (MaxPooli  (None, 3, 3, 128)         0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 1152)              0
#
#  dense_15 (Dense)            (None, 128)               147584
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 439253 (1.68 MB)
# Trainable params: 439253 (1.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %%
# Training the model
epochs = 100
batch_size = 128

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, Y_val))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 5s 379ms/step - loss: 6.3316 - accuracy: 0.1868 - val_loss: 6.2703 - val_accuracy: 0.1887
# Epoch 2/100
# 4/4 [==============================] - 1s 160ms/step - loss: 6.2434 - accuracy: 0.1962 - val_loss: 6.1872 - val_accuracy: 0.1698
# Epoch 3/100
# 4/4 [==============================] - 1s 151ms/step - loss: 6.1578 - accuracy: 0.2151 - val_loss: 6.1067 - val_accuracy: 0.1887
# Epoch 4/100
# 4/4 [==============================] - 1s 217ms/step - loss: 6.0745 - accuracy: 0.2080 - val_loss: 6.0283 - val_accuracy: 0.1887
# Epoch 5/100
# 4/4 [==============================] - 1s 148ms/step - loss: 5.9922 - accuracy: 0.2009 - val_loss: 5.9509 - val_accuracy: 0.1887
# Epoch 6/100
# 4/4 [==============================] - 0s 116ms/step - loss: 5.9106 - accuracy: 0.2057 - val_loss: 5.8719 - val_accuracy: 0.1792
# Epoch 7/100
# 4/4 [==============================] - 0s 107ms/step - loss: 5.8297 - accuracy: 0.2270 - val_loss: 5.7912 - val_accuracy: 0.1698
# Epoch 8/100
# 4/4 [==============================] - 0s 105ms/step - loss: 5.7500 - accuracy: 0.2411 - val_loss: 5.7126 - val_accuracy: 0.1792
# Epoch 9/100
# 4/4 [==============================] - 0s 105ms/step - loss: 5.6692 - accuracy: 0.2553 - val_loss: 5.6274 - val_accuracy: 0.1792
# Epoch 10/100
# 4/4 [==============================] - 0s 111ms/step - loss: 5.5872 - accuracy: 0.2459 - val_loss: 5.5602 - val_accuracy: 0.1792
# Epoch 11/100
# 4/4 [==============================] - 0s 102ms/step - loss: 5.5072 - accuracy: 0.2199 - val_loss: 5.4781 - val_accuracy: 0.1887
# Epoch 12/100
# 4/4 [==============================] - 0s 107ms/step - loss: 5.4200 - accuracy: 0.3310 - val_loss: 5.3902 - val_accuracy: 0.3679
# Epoch 13/100
# 4/4 [==============================] - 0s 106ms/step - loss: 5.3339 - accuracy: 0.4232 - val_loss: 5.2858 - val_accuracy: 0.4057
# Epoch 14/100
# 4/4 [==============================] - 0s 106ms/step - loss: 5.2358 - accuracy: 0.4303 - val_loss: 5.2096 - val_accuracy: 0.3208
# Epoch 15/100
# 4/4 [==============================] - 0s 129ms/step - loss: 5.1439 - accuracy: 0.3901 - val_loss: 5.1052 - val_accuracy: 0.3868
# Epoch 16/100
# 4/4 [==============================] - 0s 105ms/step - loss: 5.0413 - accuracy: 0.4752 - val_loss: 5.0552 - val_accuracy: 0.4434
# Epoch 17/100
# 4/4 [==============================] - 0s 104ms/step - loss: 4.9690 - accuracy: 0.4870 - val_loss: 4.9293 - val_accuracy: 0.4245
# Epoch 18/100
# 4/4 [==============================] - 0s 105ms/step - loss: 4.8896 - accuracy: 0.4870 - val_loss: 4.8790 - val_accuracy: 0.4151
# Epoch 19/100
# 4/4 [==============================] - 0s 104ms/step - loss: 4.8007 - accuracy: 0.4704 - val_loss: 4.8351 - val_accuracy: 0.4057
# Epoch 20/100
# 4/4 [==============================] - 0s 107ms/step - loss: 4.7526 - accuracy: 0.4563 - val_loss: 4.7261 - val_accuracy: 0.4528
# Epoch 21/100
# 4/4 [==============================] - 0s 130ms/step - loss: 4.6831 - accuracy: 0.5130 - val_loss: 4.6789 - val_accuracy: 0.4340
# Epoch 22/100
# 4/4 [==============================] - 0s 106ms/step - loss: 4.6017 - accuracy: 0.5177 - val_loss: 4.6161 - val_accuracy: 0.4340
# Epoch 23/100
# 4/4 [==============================] - 0s 106ms/step - loss: 4.5477 - accuracy: 0.5106 - val_loss: 4.5680 - val_accuracy: 0.4717
# Epoch 24/100
# 4/4 [==============================] - 0s 124ms/step - loss: 4.4947 - accuracy: 0.5508 - val_loss: 4.5501 - val_accuracy: 0.4340
# Epoch 25/100
# 4/4 [==============================] - 0s 108ms/step - loss: 4.4406 - accuracy: 0.5319 - val_loss: 4.5204 - val_accuracy: 0.4717
# Epoch 26/100
# 4/4 [==============================] - 0s 104ms/step - loss: 4.3862 - accuracy: 0.5461 - val_loss: 4.4458 - val_accuracy: 0.4623
# Epoch 27/100
# 4/4 [==============================] - 0s 106ms/step - loss: 4.3429 - accuracy: 0.5721 - val_loss: 4.4630 - val_accuracy: 0.4528
# Epoch 28/100
# 4/4 [==============================] - 0s 105ms/step - loss: 4.3023 - accuracy: 0.5508 - val_loss: 4.3690 - val_accuracy: 0.4811
# Epoch 29/100
# 4/4 [==============================] - 0s 105ms/step - loss: 4.2496 - accuracy: 0.5816 - val_loss: 4.3481 - val_accuracy: 0.4717
# Epoch 30/100
# 4/4 [==============================] - 0s 137ms/step - loss: 4.2020 - accuracy: 0.5839 - val_loss: 4.3150 - val_accuracy: 0.4528
# Epoch 31/100
# 4/4 [==============================] - 1s 140ms/step - loss: 4.1616 - accuracy: 0.5887 - val_loss: 4.2931 - val_accuracy: 0.5000
# Epoch 32/100
# 4/4 [==============================] - 1s 152ms/step - loss: 4.1423 - accuracy: 0.5650 - val_loss: 4.3772 - val_accuracy: 0.4811
# Epoch 33/100
# 4/4 [==============================] - 1s 141ms/step - loss: 4.1572 - accuracy: 0.5863 - val_loss: 4.2704 - val_accuracy: 0.4151
# Epoch 34/100
# 4/4 [==============================] - 1s 152ms/step - loss: 4.0547 - accuracy: 0.6147 - val_loss: 4.2330 - val_accuracy: 0.4811
# Epoch 35/100
# 4/4 [==============================] - 1s 159ms/step - loss: 4.0196 - accuracy: 0.6170 - val_loss: 4.1593 - val_accuracy: 0.4434
# Epoch 36/100
# 4/4 [==============================] - 1s 156ms/step - loss: 3.9766 - accuracy: 0.6052 - val_loss: 4.1431 - val_accuracy: 0.4811
# Epoch 37/100
# 4/4 [==============================] - 1s 174ms/step - loss: 3.9251 - accuracy: 0.6359 - val_loss: 4.1680 - val_accuracy: 0.4811
# Epoch 38/100
# 4/4 [==============================] - 1s 162ms/step - loss: 3.9106 - accuracy: 0.6170 - val_loss: 4.0897 - val_accuracy: 0.4906
# Epoch 39/100
# 4/4 [==============================] - 1s 160ms/step - loss: 3.8947 - accuracy: 0.6430 - val_loss: 4.1632 - val_accuracy: 0.5189
# Epoch 40/100
# 4/4 [==============================] - 1s 163ms/step - loss: 3.8598 - accuracy: 0.6217 - val_loss: 4.0537 - val_accuracy: 0.4717
# Epoch 41/100
# 4/4 [==============================] - 1s 132ms/step - loss: 3.8022 - accuracy: 0.6288 - val_loss: 4.0532 - val_accuracy: 0.4717
# Epoch 42/100
# 4/4 [==============================] - 1s 168ms/step - loss: 3.7969 - accuracy: 0.6430 - val_loss: 4.0057 - val_accuracy: 0.4811
# Epoch 43/100
# 4/4 [==============================] - 1s 146ms/step - loss: 3.7569 - accuracy: 0.6430 - val_loss: 4.0371 - val_accuracy: 0.5000
# Epoch 44/100
# 4/4 [==============================] - 1s 145ms/step - loss: 3.7828 - accuracy: 0.6312 - val_loss: 4.0762 - val_accuracy: 0.4434
# Epoch 45/100
# 4/4 [==============================] - 1s 154ms/step - loss: 3.7721 - accuracy: 0.6194 - val_loss: 3.9863 - val_accuracy: 0.5000
# Epoch 46/100
# 4/4 [==============================] - 0s 102ms/step - loss: 3.7155 - accuracy: 0.6170 - val_loss: 3.9483 - val_accuracy: 0.4906
# Epoch 47/100
# 4/4 [==============================] - 0s 108ms/step - loss: 3.6419 - accuracy: 0.6596 - val_loss: 3.9188 - val_accuracy: 0.5189
# Epoch 48/100
# 4/4 [==============================] - 0s 127ms/step - loss: 3.5948 - accuracy: 0.6856 - val_loss: 3.9808 - val_accuracy: 0.4906
# Epoch 49/100
# 4/4 [==============================] - 0s 104ms/step - loss: 3.5711 - accuracy: 0.6785 - val_loss: 3.8716 - val_accuracy: 0.5283
# Epoch 50/100
# 4/4 [==============================] - 0s 128ms/step - loss: 3.5518 - accuracy: 0.6572 - val_loss: 3.9530 - val_accuracy: 0.4906
# Epoch 51/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.5533 - accuracy: 0.6690 - val_loss: 3.8782 - val_accuracy: 0.5377
# Epoch 52/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.5124 - accuracy: 0.6667 - val_loss: 3.8975 - val_accuracy: 0.4906
# Epoch 53/100
# 4/4 [==============================] - 0s 106ms/step - loss: 3.4966 - accuracy: 0.6667 - val_loss: 3.8334 - val_accuracy: 0.5189
# Epoch 54/100
# 4/4 [==============================] - 0s 126ms/step - loss: 3.4523 - accuracy: 0.7045 - val_loss: 3.8099 - val_accuracy: 0.5377
# Epoch 55/100
# 4/4 [==============================] - 0s 103ms/step - loss: 3.4344 - accuracy: 0.7234 - val_loss: 3.8500 - val_accuracy: 0.5000
# Epoch 56/100
# 4/4 [==============================] - 0s 127ms/step - loss: 3.3992 - accuracy: 0.6974 - val_loss: 3.7936 - val_accuracy: 0.5283
# Epoch 57/100
# 4/4 [==============================] - 0s 109ms/step - loss: 3.4054 - accuracy: 0.6761 - val_loss: 3.8269 - val_accuracy: 0.4811
# Epoch 58/100
# 4/4 [==============================] - 0s 127ms/step - loss: 3.3546 - accuracy: 0.7258 - val_loss: 3.7559 - val_accuracy: 0.5377
# Epoch 59/100
# 4/4 [==============================] - 0s 135ms/step - loss: 3.3092 - accuracy: 0.7163 - val_loss: 3.8319 - val_accuracy: 0.4811
# Epoch 60/100
# 4/4 [==============================] - 0s 105ms/step - loss: 3.3334 - accuracy: 0.6927 - val_loss: 3.7443 - val_accuracy: 0.5189
# Epoch 61/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.3033 - accuracy: 0.7045 - val_loss: 3.7488 - val_accuracy: 0.5094
# Epoch 62/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.2806 - accuracy: 0.7069 - val_loss: 3.7638 - val_accuracy: 0.4528
# Epoch 63/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.2821 - accuracy: 0.7400 - val_loss: 3.8087 - val_accuracy: 0.4811
# Epoch 64/100
# 4/4 [==============================] - 0s 107ms/step - loss: 3.2403 - accuracy: 0.7423 - val_loss: 3.7932 - val_accuracy: 0.4340
# Epoch 65/100
# 4/4 [==============================] - 0s 129ms/step - loss: 3.2471 - accuracy: 0.7210 - val_loss: 3.7512 - val_accuracy: 0.4906
# Epoch 66/100
# 4/4 [==============================] - 0s 128ms/step - loss: 3.2016 - accuracy: 0.7258 - val_loss: 3.7691 - val_accuracy: 0.4906
# Epoch 67/100
# 4/4 [==============================] - 0s 110ms/step - loss: 3.1834 - accuracy: 0.7423 - val_loss: 3.7336 - val_accuracy: 0.4906
# Epoch 68/100
# 4/4 [==============================] - 0s 126ms/step - loss: 3.1739 - accuracy: 0.7234 - val_loss: 3.7346 - val_accuracy: 0.4906
# Epoch 69/100
# 4/4 [==============================] - 1s 147ms/step - loss: 3.1632 - accuracy: 0.7470 - val_loss: 3.7333 - val_accuracy: 0.4811
# Epoch 70/100
# 4/4 [==============================] - 1s 161ms/step - loss: 3.1981 - accuracy: 0.6998 - val_loss: 3.6355 - val_accuracy: 0.4906
# Epoch 71/100
# 4/4 [==============================] - 1s 156ms/step - loss: 3.1323 - accuracy: 0.7305 - val_loss: 3.6381 - val_accuracy: 0.5472
# Epoch 72/100
# 4/4 [==============================] - 1s 151ms/step - loss: 3.0521 - accuracy: 0.7636 - val_loss: 3.6019 - val_accuracy: 0.5377
# Epoch 73/100
# 4/4 [==============================] - 1s 156ms/step - loss: 3.0258 - accuracy: 0.7636 - val_loss: 3.5827 - val_accuracy: 0.5472
# Epoch 74/100
# 4/4 [==============================] - 1s 139ms/step - loss: 3.0055 - accuracy: 0.7683 - val_loss: 3.6120 - val_accuracy: 0.5189
# Epoch 75/100
# 4/4 [==============================] - 1s 174ms/step - loss: 2.9790 - accuracy: 0.7872 - val_loss: 3.5866 - val_accuracy: 0.5377
# Epoch 76/100
# 4/4 [==============================] - 1s 163ms/step - loss: 2.9723 - accuracy: 0.7754 - val_loss: 3.5886 - val_accuracy: 0.5283
# Epoch 77/100
# 4/4 [==============================] - 1s 156ms/step - loss: 2.9644 - accuracy: 0.7801 - val_loss: 3.6033 - val_accuracy: 0.5377
# Epoch 78/100
# 4/4 [==============================] - 1s 163ms/step - loss: 2.9711 - accuracy: 0.7612 - val_loss: 3.5602 - val_accuracy: 0.5283
# Epoch 79/100
# 4/4 [==============================] - 1s 153ms/step - loss: 2.9436 - accuracy: 0.7825 - val_loss: 3.5448 - val_accuracy: 0.5377
# Epoch 80/100
# 4/4 [==============================] - 1s 158ms/step - loss: 2.8970 - accuracy: 0.7849 - val_loss: 3.5769 - val_accuracy: 0.5094
# Epoch 81/100
# 4/4 [==============================] - 1s 161ms/step - loss: 2.8663 - accuracy: 0.8156 - val_loss: 3.5771 - val_accuracy: 0.5000
# Epoch 82/100
# 4/4 [==============================] - 1s 176ms/step - loss: 2.8533 - accuracy: 0.8132 - val_loss: 3.5270 - val_accuracy: 0.5094
# Epoch 83/100
# 4/4 [==============================] - 1s 166ms/step - loss: 2.8361 - accuracy: 0.7872 - val_loss: 3.5898 - val_accuracy: 0.5283
# Epoch 84/100
# 4/4 [==============================] - 1s 152ms/step - loss: 2.8200 - accuracy: 0.8156 - val_loss: 3.5291 - val_accuracy: 0.5377
# Epoch 85/100
# 4/4 [==============================] - 0s 110ms/step - loss: 2.7962 - accuracy: 0.8014 - val_loss: 3.5974 - val_accuracy: 0.5189
# Epoch 86/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.8182 - accuracy: 0.7943 - val_loss: 3.5291 - val_accuracy: 0.5189
# Epoch 87/100
# 4/4 [==============================] - 0s 104ms/step - loss: 2.7952 - accuracy: 0.7920 - val_loss: 3.6060 - val_accuracy: 0.5377
# Epoch 88/100
# 4/4 [==============================] - 0s 108ms/step - loss: 2.7935 - accuracy: 0.8085 - val_loss: 3.5583 - val_accuracy: 0.5000
# Epoch 89/100
# 4/4 [==============================] - 0s 107ms/step - loss: 2.7678 - accuracy: 0.8061 - val_loss: 3.5962 - val_accuracy: 0.5189
# Epoch 90/100
# 4/4 [==============================] - 0s 133ms/step - loss: 2.7579 - accuracy: 0.8251 - val_loss: 3.5562 - val_accuracy: 0.5189
# Epoch 91/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.7847 - accuracy: 0.7730 - val_loss: 3.6841 - val_accuracy: 0.5094
# Epoch 92/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.7490 - accuracy: 0.7872 - val_loss: 3.4583 - val_accuracy: 0.5000
# Epoch 93/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.7303 - accuracy: 0.8132 - val_loss: 3.5886 - val_accuracy: 0.5377
# Epoch 94/100
# 4/4 [==============================] - 0s 105ms/step - loss: 2.7365 - accuracy: 0.8038 - val_loss: 3.5305 - val_accuracy: 0.4717
# Epoch 95/100
# 4/4 [==============================] - 0s 111ms/step - loss: 2.7153 - accuracy: 0.7825 - val_loss: 3.5018 - val_accuracy: 0.5566
# Epoch 96/100
# 4/4 [==============================] - 0s 106ms/step - loss: 2.6482 - accuracy: 0.8463 - val_loss: 3.5212 - val_accuracy: 0.5377
# Epoch 97/100
# 4/4 [==============================] - 0s 111ms/step - loss: 2.6227 - accuracy: 0.8463 - val_loss: 3.4433 - val_accuracy: 0.5094
# Epoch 98/100
# 4/4 [==============================] - 0s 129ms/step - loss: 2.6004 - accuracy: 0.8700 - val_loss: 3.5140 - val_accuracy: 0.5094
# Epoch 99/100
# 4/4 [==============================] - 0s 106ms/step - loss: 2.5948 - accuracy: 0.8605 - val_loss: 3.4691 - val_accuracy: 0.5189
# Epoch 100/100
# 4/4 [==============================] - 0s 98ms/step - loss: 2.5638 - accuracy: 0.8747 - val_loss: 3.4840 - val_accuracy: 0.5189

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
# Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 17ms/step - loss: 3.3211 - accuracy: 0.6610
# Accuracy over the test set:
#   66.1 %

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  maltese_dog
# Predicted :  maltese_dog
